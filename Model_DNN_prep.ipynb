# %%
#importing necessary libraries
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM
from tensorflow.keras.preprocessing.sequence import pad_sequences
from wordcloud import WordCloud
import emoji
from nltk.corpus import stopwords
sw=stopwords

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt #importing the plotting library
import seaborn as sns

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\sssva\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
df=pd.read_excel('Group3-news-text-sanitized.xlsx') #reading the file

# %%
df = df.drop_duplicates('Tweet',keep='first') # dropping the duplicate tweets
df['Tweet'].count()
# Out:
# 10138

# %%
df["Cleaned_Tweet"] = [re.sub(r"(@[A-Za-z0–9_]+)|[^\w\s]|#|http\S+", "", v.lower()) for v in df["Tweet"]] #cleaning then data
df
# Out:
#            Category  Confidence  \
# 0          Relevant      0.3342
# 1      Not Relevant      0.3367
# 2          Relevant      0.3982
# 3      Not Relevant      0.3994
# 4          Relevant      0.3994
# ...             ...         ...
# 10318      Relevant      1.0000
# 10319      Relevant      1.0000
# 10320      Relevant      1.0000
# 10321      Relevant      1.0000
# 10322      Relevant      1.0000
#
#                                                    Tweet  \
# 0      Drowning' - Acrylic 08.05.15 https://t.co/X17f...
# 1      Check out more data on Upper Wabash reservoirs...
# 2      #tornado #singapore Mac and #cheese #around th...
# 3      WACKOES like #MicheleBachman predict the WORLD...
# 4      Australia's Ashes disaster - how the collapse ...
# ...                                                  ...
# 10318  #Sismo M 1.9 - 5km S of Volcano Hawaii: Time20...
# 10319  Thank you to @scegnews! Our neighborhood looks...
# 10320  70 years ago today the U.S.  dropped a nuclear...
# 10321  Iranian warship points weapon at U.S. helicopt...
# 10322  BREAKING: Obama Officials GAVE Muslim Terroris...
#
#                                            Cleaned_Tweet
# 0                              drowning  acrylic 080515
# 1      check out more data on upper wabash reservoirs...
# 2      tornado singapore mac and cheese around the wo...
# 3      wackoes like michelebachman predict the world ...
# 4      australias ashes disaster  how the collapse un...
# ...                                                  ...
# 10318  sismo m 19  5km s of volcano hawaii time201508...
# 10319  thank you to  our neighborhood looks like a wa...
# 10320  70 years ago today the us  dropped a nuclear w...
# 10321  iranian warship points weapon at us helicopter...
# 10322  breaking obama officials gave muslim terrorist...
#
# [10138 rows x 4 columns]

# %%
# Week 13
# Handling the text preprocessing by embedding the removal extra spaces in a sentence, Removing unwanted repeated characters from a sentence.
def normalizepreprocessdata(data):
    stop_words = set(stopwords.words('english'))
    # Removing the stop wors form the data.
    words = [word for word in data.split() if word not in stop_words]
    # Normalize emojis
    words = [emoji.demojize(tweet) for tweet in words]
    # Remove unnecessary spacing and handle repeated characters
    words = [re.sub(r'(.)\1+', r'\1\1', word.strip()) for word in words]
    words = ' '.join(words)
    return words

# %%
df["Cleaned_Tweet"] = df["Cleaned_Tweet"].apply(normalizepreprocessdata)
df
# Out:
#            Category  Confidence  \
# 0          Relevant      0.3342
# 1      Not Relevant      0.3367
# 2          Relevant      0.3982
# 3      Not Relevant      0.3994
# 4          Relevant      0.3994
# ...             ...         ...
# 10318      Relevant      1.0000
# 10319      Relevant      1.0000
# 10320      Relevant      1.0000
# 10321      Relevant      1.0000
# 10322      Relevant      1.0000
#
#                                                    Tweet  \
# 0      Drowning' - Acrylic 08.05.15 https://t.co/X17f...
# 1      Check out more data on Upper Wabash reservoirs...
# 2      #tornado #singapore Mac and #cheese #around th...
# 3      WACKOES like #MicheleBachman predict the WORLD...
# 4      Australia's Ashes disaster - how the collapse ...
# ...                                                  ...
# 10318  #Sismo M 1.9 - 5km S of Volcano Hawaii: Time20...
# 10319  Thank you to @scegnews! Our neighborhood looks...
# 10320  70 years ago today the U.S.  dropped a nuclear...
# 10321  Iranian warship points weapon at U.S. helicopt...
# 10322  BREAKING: Obama Officials GAVE Muslim Terroris...
#
#                                            Cleaned_Tweet
# 0                                drowning acrylic 080515
# 1                check data upper wabash reservoirs site
# 2      tornado singapore mac cheese around world mac ...
# 3      wackoes like michelebachman predict world soon...
# 4      australias ashes disaster collapse unfolded tr...
# ...                                                  ...
# 10318  sismo 19 5km volcano hawaii time20150806 01040...
# 10319  thank neighborhood looks like war zone power b...
# 10320  70 years ago today us dropped nuclear weapon j...
# 10321  iranian warship points weapon us helicopter of...
# 10322  breaking obama officials gave muslim terrorist...
#
# [10138 rows x 4 columns]

# %%
df.drop('Tweet',axis=1) #dropping the actual column of tweets
# Out:
#            Category  Confidence  \
# 0          Relevant      0.3342
# 1      Not Relevant      0.3367
# 2          Relevant      0.3982
# 3      Not Relevant      0.3994
# 4          Relevant      0.3994
# ...             ...         ...
# 10318      Relevant      1.0000
# 10319      Relevant      1.0000
# 10320      Relevant      1.0000
# 10321      Relevant      1.0000
# 10322      Relevant      1.0000
#
#                                            Cleaned_Tweet
# 0                                drowning acrylic 080515
# 1                check data upper wabash reservoirs site
# 2      tornado singapore mac cheese around world mac ...
# 3      wackoes like michelebachman predict world soon...
# 4      australias ashes disaster collapse unfolded tr...
# ...                                                  ...
# 10318  sismo 19 5km volcano hawaii time20150806 01040...
# 10319  thank neighborhood looks like war zone power b...
# 10320  70 years ago today us dropped nuclear weapon j...
# 10321  iranian warship points weapon us helicopter of...
# 10322  breaking obama officials gave muslim terrorist...
#
# [10138 rows x 3 columns]

# %%
vals_to_replace = {'Relevant':1, 'Not Relevant':0} # Define a dictionary to map the string values to their corresponding integer replacements
# Use the 'map()' function to replace values in the 'Category' column of the DataFrame 'df'
# The map() function applies the replacements specified in the 'vals_to_replace' dictionary to each element of the 'Category' column.
df['Category'] = df['Category'].map(vals_to_replace)
# After running this code, the 'Category' column in the DataFrame 'df' will have its string values replaced with corresponding integer values based on the 'vals_to_replace' dictionary.
# For example, if the original 'Category' column had 'Relevant' and 'Not Relevant' as its values, they will be replaced with 1 and 0, respectively.
# Other values in the 'Category' column will remain unchanged.

# %%
df.dropna(inplace=True)

# %%
df['Category'].unique()
# Out:
# array([1., 0.])

# %%
# Split the DataFrame 'df' into training and testing sets for input features ('Cleaned_Tweet') and target labels ('Category')
# test_size=0.2 specifies that 20% of the data will be used for testing, and 80% will be used for training
# random_state=42 sets a specific seed value for the random number generator, ensuring reproducibility of the split
# This means that every time this code is run with random_state=42, the same random split will be generated.
X_train, X_test, y_train, y_test = train_test_split(df['Cleaned_Tweet'], df['Category'], test_size=0.2, random_state=42)
# X_train: This contains 80% of the 'Cleaned_Tweet' data and will be used for training the model.
# X_test: This contains the remaining 20% of the 'Cleaned_Tweet' data and will be used for evaluating the model's performance.
# y_train: This contains the corresponding target labels (0 or 1) for the tweets in X_train and will be used during training.
# y_test: This contains the corresponding target labels (0 or 1) for the tweets in X_test and will be used for evaluating the model's performance.

# %%
tokenizer = Tokenizer() #Initialize a new Tokenizer object
tokenizer.fit_on_texts(X_train)  # Fit the Tokenizer on the training data (X_train)
X_train_sequences = tokenizer.texts_to_sequences(X_train) # Convert the text data in X_train to sequences of integers
X_test_sequences = tokenizer.texts_to_sequences(X_test) # Convert the text data in X_test to sequences of integers
# X_train_sequences: This contains the training data (tweets) represented as sequences of integers, where each integer represents a unique word in the tokenizer's vocabulary.
# X_test_sequences: This contains the testing data (tweets) represented as sequences of integers using the same tokenizer's vocabulary as X_train_sequences.

# %%
max_sequence_length = 100  # Define the maximum sequence length to which the sequences will be padded
X_train_padded = pad_sequences(X_train_sequences, maxlen=max_sequence_length) # Pad the sequences in X_train_sequences to ensure they all have the same length (max_sequence_length)
X_test_padded = pad_sequences(X_test_sequences, maxlen=max_sequence_length) # Pad the sequences in X_test_sequences to ensure they all have the same length (max_sequence_length)
# Padding ensures that all input sequences have the same length, which is essential for efficient batch processing during model training and evaluation.

# %%
from keras.layers import Dense, Activation, Flatten,Dropout #importing dense, activation, flatten and dropout layers from keras

# %%
model = Sequential() # Create a sequential model
model.add(Embedding(len(tokenizer.word_index) + 1, 32, input_length=max_sequence_length))  # Add the Embedding layer
model.add(LSTM(64, return_sequences=True)) # Add the first LSTM layer with return_sequences=True
model.add(LSTM(64)) # Add the second LSTM layer without returning sequences (outputting only the final LSTM state)
model.add(Dense(1, activation='sigmoid')) # Add the final Dense layer with one neuron and a sigmoid activation function for binary classification

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # Compile the model with the specified loss function, optimizer, and evaluation metrics
# binary_crossentropy is the loss function used for binary classification tasks
model.fit(X_train_padded, y_train, validation_data=(X_test_padded, y_test), epochs=5, batch_size=32)  # Train the model on the training data (X_train_padded) and corresponding labels (y_train)
# epochs=5 specifies the number of times the model will iterate over the entire training dataset during training.
# batch_size=32 specifies the number of samples per gradient update. The model's weights are updated after processing each batch.
# Out:
# Epoch 1/5
# 254/254 [==============================] - 21s 74ms/step - loss: 0.5358 - accuracy: 0.7253 - val_loss: 0.4403 - val_accuracy: 0.8084
# Epoch 2/5
# 254/254 [==============================] - 20s 79ms/step - loss: 0.3003 - accuracy: 0.8770 - val_loss: 0.4752 - val_accuracy: 0.7862
# Epoch 3/5
# 254/254 [==============================] - 25s 97ms/step - loss: 0.1860 - accuracy: 0.9311 - val_loss: 0.5679 - val_accuracy: 0.7872
# Epoch 4/5
# 254/254 [==============================] - 24s 93ms/step - loss: 0.1286 - accuracy: 0.9559 - val_loss: 0.7156 - val_accuracy: 0.7768
# Epoch 5/5
# 254/254 [==============================] - 22s 88ms/step - loss: 0.1035 - accuracy: 0.9660 - val_loss: 0.7688 - val_accuracy: 0.7719

# %%
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix #importing the auc curve, roc curve and confusion matrix

# %%
y_pred = model.predict(X_test_padded) # Predict the probabilities for the positive class (class 1) using the trained model and the testing data (X_test_padded)
auc = roc_auc_score(y_test, y_pred)  # Calculate the ROC AUC score by comparing the predicted probabilities (y_pred) to the true labels (y_test).
print("AUC:", auc) #printing accuracy
# Out:
# 64/64 [==============================] - 3s 27ms/step
# AUC: 0.8247200732085485

# %%
y_pred_binary = (y_pred > 0.5).astype(int)

# %%
# Calculate confusion matrix
confusionmetrices = confusion_matrix(y_test, y_pred_binary)
print("Confusion Matrix:")
print(confusionmetrices)

clabel = ["Positive","Negative"]
plt.figure(figsize=(8,6))
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Confusion Matrix")
sns.heatmap(confusionmetrices, annot=True, fmt="d", cmap="viridis",xticklabels=clabel, yticklabels=clabel)
plt.show()
# Out:
# Confusion Matrix:
# [[972 196]
#  [266 591]]

# %%
# Finding out misclassified tweet w.r.t to the actual and predicted labels
misclassified_indices = [indx for indx, (truelabel, predlabel) in enumerate(zip(y_test, y_pred_binary)) if truelabel != predlabel]
print("Total Misclassified tweets - " + str(len(misclassified_indices)) + "\n")

for idx in misclassified_indices:
    truelabel = y_test.iloc[idx]
    predlabel = y_pred_binary[idx][0]
    tweet = X_test.iloc[idx]
    print(f"Actual: " + str(truelabel) + " Predicted: " + str(predlabel) + " Tweet: " + tweet)
# Out:
# Total Misclassified tweets - 462
#
# Actual: 1.0 Predicted: 0 Tweet: chinas ecommerce firms alibaba baba tencent jd still growing revenue 40
# Actual: 0.0 Predicted: 1 Tweet: brooklyn locksmith domesticate emergency mechanic services circa clock movement gba
# Actual: 0.0 Predicted: 1 Tweet: 7 injured pro bowl back
# Actual: 0.0 Predicted: 1 Tweet: im experienced injuries waist
# Actual: 0.0 Predicted: 1 Tweet: trusting iran stop terrorism like inviting arsonist join fire brigade telegraph
# Actual: 1.0 Predicted: 0 Tweet: citation billings police officer caused broadwater crash
# Actual: 1.0 Predicted: 0 Tweet: kessler syndrome name catastrophic exponential proliferation space debris destruction satellites gravitymovie
# Actual: 0.0 Predicted: 1 Tweet: new nanotech device able target destroy blood clots
# Actual: 1.0 Predicted: 0 Tweet: debatequestionswewanttohear u start another war would u b willing 2 go 2 warzone send ur sons andor daughters 2 fight
# Actual: 0.0 Predicted: 1 Tweet: day 1 tryouts went good minus fact stopped quickly get short ball annihilated toenail injury even
# Actual: 0.0 Predicted: 1 Tweet: could slit throat id apologize bleeding
# Actual: 0.0 Predicted: 1 Tweet: reddit quarantine offensive content onlinecommunities reddit via
# Actual: 1.0 Predicted: 0 Tweet: pls reduce cyclist deaths compulsory highway code test every vehicle uses road notrocketscience
# Actual: 0.0 Predicted: 1 Tweet: bar method integrates fat burning format interval training muscle shaping techniqu
# Actual: 1.0 Predicted: 0 Tweet: oops bounty hunters try raid phoenix police chiefs home group armed bounty
# Actual: 1.0 Predicted: 0 Tweet: salha1harry styles2u know ur p_eoplehurryevacuate fromhelljust shahadaamppickmeclass_sick
# Actual: 1.0 Predicted: 0 Tweet: learned economics one south dakota dust storm years college hubert humphrey
# Actual: 1.0 Predicted: 0 Tweet: hell fraction belief total annihilation destruction usa
# Actual: 1.0 Predicted: 0 Tweet: memphis always floods
# Actual: 1.0 Predicted: 0 Tweet: week received sad news friends daughters cancer prognosis second upheaval
# Actual: 1.0 Predicted: 0 Tweet: football hooligan jailed rioting game scotland already banned matches england uknews
# Actual: 1.0 Predicted: 0 Tweet: wtf cant love bit really think thats feels massive crush got crushed
# Actual: 0.0 Predicted: 1 Tweet: kids bedtime gotten later amp later nows good time point regular curfew would btsprep parenting
# Actual: 1.0 Predicted: 0 Tweet: hey royals love damage 2 outs
# Actual: 0.0 Predicted: 1 Tweet: hermancranston atk letsfootball rt skanndtyagi letsfootball atk wired fires burning _
# Actual: 0.0 Predicted: 1 Tweet: 670thescore wld b shame golf cart became engulfed flames boycottbears
# Actual: 1.0 Predicted: 0 Tweet: ipod crashed weloveyoulouis mtvhottest one direction
# Actual: 0.0 Predicted: 1 Tweet: best evidence word guy encouraged suicide bombing means get heavenwell
# Actual: 1.0 Predicted: 0 Tweet: think typhoon passed lol
# Actual: 0.0 Predicted: 1 Tweet: 5sos thanks damn heart attack
# Actual: 0.0 Predicted: 1 Tweet: today fell rock scraped whole butt nearly drowned summer2k15
# Actual: 1.0 Predicted: 0 Tweet: 86 nit change fact extracting hostages pointless
# Actual: 0.0 Predicted: 1 Tweet: think none us know impact lives around us even slightest stirring create violent storm
# Actual: 1.0 Predicted: 0 Tweet: burning enemity pakistan sure burn
# Actual: 1.0 Predicted: 0 Tweet: bolshevik government monopolized food supply seize power hunhry population artificial famine result
# Actual: 1.0 Predicted: 0 Tweet: civilian population ever deserves demolition may never forget amp learn mistakes hiroshima
# Actual: 1.0 Predicted: 0 Tweet: didnt even notice background im floatin head bombed
# Actual: 1.0 Predicted: 0 Tweet: hear sirens
# Actual: 1.0 Predicted: 0 Tweet: listen wtm avalanche take deep breath
# Actual: 1.0 Predicted: 0 Tweet: cyprus news analysis mullah omars death may split talibans ranks omars demise would certainly lead
# Actual: 0.0 Predicted: 1 Tweet: plan emergency preparedness families children special needs autism specialneeds
# Actual: 1.0 Predicted: 0 Tweet: kca votejkt48id joelheyman loose understanding 750k subs ah electrocute eat michael dont want 2 influence anythin_
# Actual: 1.0 Predicted: 0 Tweet: 1 russia may played reason link bs okanowa bloody mainline invasion looked like bloody
# Actual: 0.0 Predicted: 1 Tweet: maybe call israel tell sorry pres sold river annihilation
# Actual: 1.0 Predicted: 0 Tweet: html5 beginners crash course course
# Actual: 1.0 Predicted: 0 Tweet: man crushed death car
# Actual: 0.0 Predicted: 1 Tweet: call fag im going call ambulance rainbowpower
# Actual: 1.0 Predicted: 0 Tweet: three beached whales rescued kerry
# Actual: 1.0 Predicted: 0 Tweet: 379 suspected kerry barry got taken ride iran making bomb talks went
# Actual: 1.0 Predicted: 0 Tweet: peacetime times national emergency
# Actual: 0.0 Predicted: 1 Tweet: state sponsored terrorism
# Actual: 0.0 Predicted: 1 Tweet: socialism means mass murder houze correlation
# Actual: 1.0 Predicted: 0 Tweet: 72 thousands people displacedinjuredkilled hey theres opportunity different restaurants
# Actual: 1.0 Predicted: 0 Tweet: california school bus hijacker parole stands sacramento
# Actual: 1.0 Predicted: 0 Tweet: 15 fire thatd safety hazard
# Actual: 0.0 Predicted: 1 Tweet: notley flattened harper heartland harper imported tens thousands tfw slaves cost albertans jobs
# Actual: 1.0 Predicted: 0 Tweet: wars doomed destruction loss money must invest irans inside go outside
# Actual: 0.0 Predicted: 1 Tweet: last retweet would think lion saved people burning buildings deep
# Actual: 0.0 Predicted: 1 Tweet: ah yes gays totally destroying america see buildings burning meteors crashing schools wow
# Actual: 1.0 Predicted: 0 Tweet: mom fights recover hospital fiery car crash kids miss home
# Actual: 1.0 Predicted: 0 Tweet: like could danger something
# Actual: 1.0 Predicted: 0 Tweet: bloody hell already upgraded rioting hyperbole saintsfc
# Actual: 1.0 Predicted: 0 Tweet: tnn chinas stock market crash gems rubble
# Actual: 0.0 Predicted: 1 Tweet: survived plague floated flood peeked heads mud ones immune deafening bells god survive
# Actual: 0.0 Predicted: 1 Tweet: proud watching copalibertadores argentinean pandemonium
# Actual: 0.0 Predicted: 1 Tweet: 71 tragedy commons pertains public ownership property rights based markets opposite say
# Actual: 0.0 Predicted: 1 Tweet: light rain forecast based dressing light rain incessant deluge
# Actual: 0.0 Predicted: 1 Tweet: please check salt river horses help stop annihilation happen without 5400 signatureschange org thx
# Actual: 1.0 Predicted: 0 Tweet: fuck going trent bridge reminds englands collapse caribbean back 90s
# Actual: 0.0 Predicted: 1 Tweet: jax issues hazardous weather outlook hwo
# Actual: 1.0 Predicted: 0 Tweet: 76 one good thing came watching film traumatised watch show started halt amp catch fire amazon
# Actual: 1.0 Predicted: 0 Tweet: body bagging mfs
# Actual: 0.0 Predicted: 1 Tweet: bairstow dropped buffet ticket devastated lad
# Actual: 0.0 Predicted: 1 Tweet: quirk injury laws news stories via
# Actual: 1.0 Predicted: 0 Tweet: kosciusko police investigating pedestrian fatality hit train thursday
# Actual: 0.0 Predicted: 1 Tweet: ok wasnt completely forthright may also food coma bc kebabtahinipickles also annihilated wfries
# Actual: 0.0 Predicted: 1 Tweet: else wants documents radiation emergency procedures 06 24 09 radiation emergency procedures 06 24 09
# Actual: 1.0 Predicted: 0 Tweet: 500 deaths year foodborne illness dears
# Actual: 0.0 Predicted: 1 Tweet: swansea plot hijack transfer move southampton target virgil van dijk
# Actual: 1.0 Predicted: 0 Tweet: hollywood movie trapped miners released chile 33 hollywood movie trapped miners starring
# Actual: 0.0 Predicted: 1 Tweet: georgian wines become casualty russias political campaign ukraine
# Actual: 1.0 Predicted: 0 Tweet: emergency odai bucharest romania 600 dogs dyingthey hungry eat
# Actual: 0.0 Predicted: 1 Tweet: new giant flames giant manly brown infoorder sms087809233445 pin2327564d
# Actual: 0.0 Predicted: 1 Tweet: afghan peace talks doubt mullah omars death financial times mullah
# Actual: 1.0 Predicted: 0 Tweet: buildings fire time business meeting thestrain
# Actual: 0.0 Predicted: 1 Tweet: hot funtenna hijacking computers send data sound waves black hat 2015 prebreak best
# Actual: 1.0 Predicted: 0 Tweet: omg dont believe rip bro airplane accident jetengine turbojet boing g90
# Actual: 1.0 Predicted: 0 Tweet: spd officer shot please pray please pray shreveport police department first responders
# Actual: 1.0 Predicted: 0 Tweet: fire hazard associated installation noncompliant external cladding cbplawyers
# Actual: 0.0 Predicted: 1 Tweet: outrage dog found buried alive rubble
# Actual: 0.0 Predicted: 1 Tweet: highlight day playing raw volcano humidifier sicklife
# Actual: 1.0 Predicted: 0 Tweet: antifracking group seeks review lancashire seismic monitoring fracking
# Actual: 1.0 Predicted: 0 Tweet: gujaratriot amp mumbairiot9293 devastated 100amp100 indianperpetrated modi amp chawalchorbjp
# Actual: 1.0 Predicted: 0 Tweet: heroes springer spaniel amp dog dad rescued stranded baby dolphin
# Actual: 1.0 Predicted: 0 Tweet: cw500 dealing disaster
# Actual: 0.0 Predicted: 1 Tweet: army names 10th mountain units iraq afghanistan deployments deeds
# Actual: 1.0 Predicted: 0 Tweet: pbban temporary300 hyider_ghost2 armageddon kill flags fast xp reason
# Actual: 0.0 Predicted: 1 Tweet: new us counter terrorism program urges muslims rat critics say
# Actual: 0.0 Predicted: 1 Tweet: also iphone charger broken electrocuted
# Actual: 0.0 Predicted: 1 Tweet: ted cruz bashes obama comparison gop iranians shouting death america
# Actual: 0.0 Predicted: 1 Tweet: 28 remember beau collided slip slide died
# Actual: 0.0 Predicted: 1 Tweet: pledge allegiance pope burning buildings epic city
# Actual: 1.0 Predicted: 0 Tweet: rt hamosh84 saudi coming home yemen body bags saudi kingdom ego youre loo_
# Actual: 0.0 Predicted: 1 Tweet: got pretty windy damage
# Actual: 1.0 Predicted: 0 Tweet: 36 years ago today baseball lost one greats airplane accident rip captain yankees
# Actual: 0.0 Predicted: 1 Tweet: latest post bayelsa poll tension bayelsa patience jonathan plans hijack apc pdp
# Actual: 0.0 Predicted: 1 Tweet: trying get higher bathroom work pen b4 go demolish food
# Actual: 0.0 Predicted: 1 Tweet: look state actions year fergusons upheaval
# Actual: 1.0 Predicted: 0 Tweet: violent forces radio playing acid storm scourgue gods tunein player
# Actual: 1.0 Predicted: 0 Tweet: mudslide
# Actual: 0.0 Predicted: 1 Tweet: rioting happy valley penn state loses
# Actual: 0.0 Predicted: 1 Tweet: say bad things happen reason wise words gonna stop te bleeding
# Actual: 1.0 Predicted: 0 Tweet: everybody like fuck curfew im sitting like ill bed 12
# Actual: 0.0 Predicted: 1 Tweet: governor allows parole california school bus hijacker fresno linked local network
# Actual: 0.0 Predicted: 1 Tweet: exploration takes seismic shift gabon somalia worldoil subscription somalia
# Actual: 1.0 Predicted: 0 Tweet: exactly curfew like situation sit dad
# Actual: 1.0 Predicted: 0 Tweet: cruise industry supports mass murder whales faroe islands everything cont
# Actual: 1.0 Predicted: 0 Tweet: wanted see info blight u got
# Actual: 0.0 Predicted: 1 Tweet: trident 90225 chevy fire truck w pumper ims fire dept red ho 187 plastic
# Actual: 1.0 Predicted: 0 Tweet: near sand half sunk shattered visage lies
# Actual: 1.0 Predicted: 0 Tweet: ready heat wave dont want sun come back im enjoying break cooler temps
# Actual: 1.0 Predicted: 0 Tweet: 52214904 5139055 nuke please target hilversum please detonate 800 meters surface
# Actual: 0.0 Predicted: 1 Tweet: nuclearpower global nuclear reactor construction market grew 45 2013 2014 _ nuclear reactor co
# Actual: 0.0 Predicted: 1 Tweet: alaskas wolves face catastrophe denali wolves population plummeted 48 savedenaliwolves tweetstorm
# Actual: 1.0 Predicted: 0 Tweet: thats good hear mine could better manage alright bioterrorism doesnt wait
# Actual: 0.0 Predicted: 1 Tweet: volcano
# Actual: 1.0 Predicted: 0 Tweet: storm rolling hilton head gonna fun
# Actual: 1.0 Predicted: 0 Tweet: money cant buy happiness lie tell poor people keep rioting
# Actual: 0.0 Predicted: 1 Tweet: devastation coming find closed momneedscoffee asap iwontmakeit
# Actual: 1.0 Predicted: 0 Tweet: night kampers go vacation end dream job party fire truck sprays pool hose
# Actual: 0.0 Predicted: 1 Tweet: keep eye well looking lots new team members coming daysweeks
# Actual: 1.0 Predicted: 0 Tweet: fire catalinas gets worse evacuate area aka school tomorrow
# Actual: 1.0 Predicted: 0 Tweet: u fatality like corpse still jittering
# Actual: 1.0 Predicted: 0 Tweet: scary stuff san antonio stars head coach dan hughes run sidelines fell chairs onto floor stretcher
# Actual: 0.0 Predicted: 1 Tweet: hillary mass murderer
# Actual: 1.0 Predicted: 0 Tweet: wanted watch paper towns buildings fire
# Actual: 0.0 Predicted: 1 Tweet: funtenna hijacking computers send data sound waves black hat 2015
# Actual: 0.0 Predicted: 1 Tweet: aug 5 fort calhoun nuclear station 100 capacity today according nrc
# Actual: 0.0 Predicted: 1 Tweet: screaming internally cover prodigy graphic novel june day
# Actual: 0.0 Predicted: 1 Tweet: wackoes like michelebachman predict world soon obliterated burning firey inferno cant accept globalwarming hello
# Actual: 1.0 Predicted: 0 Tweet: cant believe blevins got injured falling curb thats something would happen never expected pro player
# Actual: 1.0 Predicted: 0 Tweet: walking past fire house today amp soon walk doors get call flip sirens ive never ran fast
# Actual: 1.0 Predicted: 0 Tweet: india shud give evidence 2 pakthey share terrorists amp use next attackshare oth contries
# Actual: 1.0 Predicted: 0 Tweet: boy mix ultimate preparedness library prepare catastrophe 10
# Actual: 0.0 Predicted: 1 Tweet: walmart taking steps keep children safe hot vehicles take look innovative car seat
# Actual: 1.0 Predicted: 0 Tweet: physical sense helps preserve memories 2011 triple disaster 84 ajw jishin_e nuclear minamisoma
# Actual: 0.0 Predicted: 1 Tweet: seattles demolitiondodging house live affordable housing
# Actual: 1.0 Predicted: 0 Tweet: daviesmutia breaking news unconfirmed heard loud bang nearby appears blast wind neighbours ass
# Actual: 0.0 Predicted: 1 Tweet: 360wisenews chinas stock market crash gems rubble
# Actual: 1.0 Predicted: 0 Tweet: dont im panicking
# Actual: 1.0 Predicted: 0 Tweet: eugene fires gotta make think hashtag conspiracies hashtag population control hashtag bush
# Actual: 0.0 Predicted: 1 Tweet: sinkhole selfies wont believe whats brooklyn sinkhole sinkhole selfies wont belie
# Actual: 1.0 Predicted: 0 Tweet: 301dc hate white people mo
# Actual: 1.0 Predicted: 0 Tweet: hiring click apply rn iiemergency servicesft7p7a nursing houston tx
# Actual: 1.0 Predicted: 0 Tweet: resistance wages guerrilla warfare kpa forces red zone wartorn outskirts
# Actual: 0.0 Predicted: 1 Tweet: pharrell prevent forest fires
# Actual: 1.0 Predicted: 0 Tweet: pandemonium aba woman delivers baby without face photos
# Actual: 1.0 Predicted: 0 Tweet: could billboards hot 100 chart displaced socialmediadriven music charts
# Actual: 1.0 Predicted: 0 Tweet: miners strike botha apartheid sa tutu nobel prize ira bomb brighton famine ethiopia 84 feels like yesterday
# Actual: 0.0 Predicted: 1 Tweet: famp things gishwhes got soaked deluge going pads tampons thx
# Actual: 0.0 Predicted: 1 Tweet: mended finger finger cut immediate reaction bodys emergency services occurs
# Actual: 1.0 Predicted: 0 Tweet: hollywood movie trapped miners released chile 33 hollywood movie trapped miners starring
# Actual: 0.0 Predicted: 1 Tweet: trafford centre film fans angry odeon cinema evacuated following false fire alarm
# Actual: 0.0 Predicted: 1 Tweet: rare vintage collectable windriver avalanche edt 60ml spray mendeals_uk
# Actual: 1.0 Predicted: 0 Tweet: annihilated damascus syrian army grinds alloosh gang manure pile
# Actual: 1.0 Predicted: 0 Tweet: drowning acrylic 080515
# Actual: 1.0 Predicted: 0 Tweet: woke loudest thunderstorm ive ever heard
# Actual: 1.0 Predicted: 0 Tweet: autoinsurance industry clueless driverless cars healthinsurance
# Actual: 0.0 Predicted: 1 Tweet: horror community deluged cruddy ostensibly macabre photography dont contribute pandemic
# Actual: 0.0 Predicted: 1 Tweet: sassy city girl country hunk stranded smoky mountain snowstorm aoms ibooklove bookboost
# Actual: 1.0 Predicted: 0 Tweet: liked video huge building explosion 2500fps slow mo guys
# Actual: 1.0 Predicted: 0 Tweet: happy received text parasite dangeri transplantee amp virus kill kidney
# Actual: 1.0 Predicted: 0 Tweet: opposite love fear heres
# Actual: 0.0 Predicted: 1 Tweet: replacing fear unknown curiosity open to_
# Actual: 1.0 Predicted: 0 Tweet: dying lyme disease case fatality rate nearly 100
# Actual: 1.0 Predicted: 0 Tweet: fam evacuate bc need power
# Actual: 1.0 Predicted: 0 Tweet: baby girls car wreak afternoon thank god serious injuries wearing seatbelt
# Actual: 1.0 Predicted: 0 Tweet: little girl next sees spot lights sky screams mom look see angels sky
# Actual: 0.0 Predicted: 1 Tweet: 2 south gate police officers 2 huntington park officers arrested child abuse investigation boot camp
# Actual: 1.0 Predicted: 0 Tweet: detonation fashionable mountaineering electronic watch waterresistant couples leisure tab_
# Actual: 1.0 Predicted: 0 Tweet: bigamist first wife charged deaths second pregnant wife child 8 mother_
# Actual: 0.0 Predicted: 1 Tweet: get emergency edmonton locksmith services edmonton canada business name got locked locksmith edmonton
# Actual: 0.0 Predicted: 1 Tweet: able stay work week take online courses property casualty state_
# Actual: 1.0 Predicted: 0 Tweet: vacation update great aunt killed spider bare hand screamed fear fierce
# Actual: 1.0 Predicted: 0 Tweet: take suit wouldnt surprised hear face belonged another democrat massmurderer
# Actual: 0.0 Predicted: 1 Tweet: doone silver architects permission demolish birminghams natwest tower replace citys tallest building
# Actual: 0.0 Predicted: 1 Tweet: join charity 10k run event 11am start sun 20 sept 2015 castle donington community first responders
# Actual: 0.0 Predicted: 1 Tweet: found diamond rubble
# Actual: 1.0 Predicted: 0 Tweet: sustainability task force presents levy fund emergency services wdtv
# Actual: 0.0 Predicted: 1 Tweet: would trapped collapsed circus tent bunch clowns
# Actual: 0.0 Predicted: 1 Tweet: cant sinkhole swallowed every taco place neighborhood
# Actual: 0.0 Predicted: 1 Tweet: look broken bleeding
# Actual: 0.0 Predicted: 1 Tweet: actually dont see hunter hayes lady antebellum perform begins live devastated person
# Actual: 0.0 Predicted: 1 Tweet: good play along may begin operation death star evacuation nearly complete
# Actual: 1.0 Predicted: 0 Tweet: burned dog finds new home young burn victim
# Actual: 0.0 Predicted: 1 Tweet: look like mass murderer
# Actual: 1.0 Predicted: 0 Tweet: migrants drowning erecting monuments 100 years shed tears powerful nations greed letting die
# Actual: 0.0 Predicted: 1 Tweet: hot funtenna hijacking computers send data sound waves black hat 2015 prebreak best
# Actual: 0.0 Predicted: 1 Tweet: times desolation trouble daniels persistent prayers fastings brought forth heavenly power god i_
# Actual: 0.0 Predicted: 1 Tweet: currently blasting benediction sanelesstheory metal devastation radio
# Actual: 1.0 Predicted: 0 Tweet: kirsten gillibrand extend health care 911 first responders
# Actual: 1.0 Predicted: 0 Tweet: never knew relationship btwn kansas city hyatt bridge collapse amp aias cote via
# Actual: 0.0 Predicted: 1 Tweet: faan orders evacuation abandoned aircraft mma via
# Actual: 1.0 Predicted: 0 Tweet: standard damage control
# Actual: 1.0 Predicted: 0 Tweet: pretty disaster gbbo mudslide
# Actual: 1.0 Predicted: 0 Tweet: good news adam barton survived helicopter crash emmerdale maybe start training amp get match fit pompey
# Actual: 1.0 Predicted: 0 Tweet: way seemeth right unto man end thereof ways death
# Actual: 1.0 Predicted: 0 Tweet: money grubbing kikes need get cluei money still destroy telekinesis watch
# Actual: 0.0 Predicted: 1 Tweet: wheres story anybody injured happen
# Actual: 1.0 Predicted: 0 Tweet: storm came fuck cool
# Actual: 1.0 Predicted: 0 Tweet: builder dental emergency ruined plan emotionally blackmail afternoon bump
# Actual: 1.0 Predicted: 0 Tweet: 1 believe weve much rain newly planted maple trees actually drowning
# Actual: 1.0 Predicted: 0 Tweet: hi ashayo believe vods youtube presentation nothing like seeing live
# Actual: 1.0 Predicted: 0 Tweet: nycha says pipe burst flooded apartments senior center repaired
# Actual: 1.0 Predicted: 0 Tweet: rt south sudans war women survivors say rape become normal thing
# Actual: 1.0 Predicted: 0 Tweet: apollo brown detonate ft mop fiya
# Actual: 1.0 Predicted: 0 Tweet: panda trapped dogs body
# Actual: 1.0 Predicted: 0 Tweet: even u weapon badge gonna put choppas ass
# Actual: 0.0 Predicted: 1 Tweet: still mortified went roses collapsed heels face planted front everyone broke fav shoes
# Actual: 0.0 Predicted: 1 Tweet: loud bang froze spot slowly every head turned towards one things hated
# Actual: 1.0 Predicted: 0 Tweet: emergency flow mp3 rar
# Actual: 0.0 Predicted: 1 Tweet: dear anyone family alive 2040 climatechange gopdebate
# Actual: 1.0 Predicted: 0 Tweet: 1961 les wozni hospital broke leg trapped cave press photo
# Actual: 1.0 Predicted: 0 Tweet: potus strategicpatience strategy genocide refugees idp internally displaced people horror etc
# Actual: 1.0 Predicted: 0 Tweet: ppl living w hiv charged aggravated assault bioterrorism things w low risk transmission hivisnotacrime
# Actual: 1.0 Predicted: 0 Tweet: nar phuket ultimate preparedness library prepare catastrophe
# Actual: 0.0 Predicted: 1 Tweet: may know roles terrorist 4
# Actual: 0.0 Predicted: 1 Tweet: great british ltbgtbakeltbgt offs back dorrets ltbgtchocolateltbgt gateau collapsed jan_
# Actual: 1.0 Predicted: 0 Tweet: must black folks dont wanna stir trouble turn causes silent injustice wrld
# Actual: 1.0 Predicted: 0 Tweet: michael talking electrocuted omg rowysolouisville
# Actual: 1.0 Predicted: 0 Tweet: eric clapton shot sheriff 1974 guess many people rioting right none
# Actual: 0.0 Predicted: 1 Tweet: room looks like tornado passed ocd
# Actual: 1.0 Predicted: 0 Tweet: dude smoking fucking thing went flames though bomb went omg scared
# Actual: 0.0 Predicted: 1 Tweet: might go losing n drive cliff fall void
# Actual: 0.0 Predicted: 1 Tweet: tragedy life ends soon wait long begin wm lewis quotes
# Actual: 0.0 Predicted: 1 Tweet: hot funtenna hijacking computers send data sound waves black hat 2015 prebreak best
# Actual: 0.0 Predicted: 1 Tweet: personal favorites include paramore muse green day royal blood 5sos
# Actual: 0.0 Predicted: 1 Tweet: harper gets sassed albertans calling ndp government disaster via harperblamesalbertans
# Actual: 1.0 Predicted: 0 Tweet: detroit made progress blight many burned shells houses remain
# Actual: 1.0 Predicted: 0 Tweet: sandstorm woo hoo
# Actual: 1.0 Predicted: 0 Tweet: prediction vikings game sundaydont expect whole lot infact think zimmer goal isinjury free 1st game
# Actual: 1.0 Predicted: 0 Tweet: caught landslide
# Actual: 1.0 Predicted: 0 Tweet: must get hot burning buildings loses followers
# Actual: 0.0 Predicted: 1 Tweet: learning legacy catastrophic eruption new yorker
# Actual: 0.0 Predicted: 1 Tweet: better tornado
# Actual: 1.0 Predicted: 0 Tweet: thunder shook house woke sister made car alarms go
# Actual: 1.0 Predicted: 0 Tweet: ill sfa soonpandemonium
# Actual: 0.0 Predicted: 1 Tweet: 360wisenews chinas stock market crash gems rubble
# Actual: 1.0 Predicted: 0 Tweet: patientreported outcomes longterm survivors metastatic colorectal cancer british journal surgery
# Actual: 1.0 Predicted: 0 Tweet: thisdayinhistory 1862 confederate ship blown crew read via
# Actual: 0.0 Predicted: 1 Tweet: first stearns grenade thought wwiiera one apparently newer bomb squad plans detonate around 8 pm
# Actual: 0.0 Predicted: 1 Tweet: im cook smokey bear saving forest fires face ass
# Actual: 0.0 Predicted: 1 Tweet: jeff bullied sally raped ben drowned hoodie betrayed lj abandoned ej sacrifice lost
# Actual: 0.0 Predicted: 1 Tweet: warfighting robots could reduce civilian casualties calling ban premature
# Actual: 1.0 Predicted: 0 Tweet: 46 returned refugees fleeing amp vietnamese govt treat returned dutton presser
# Actual: 0.0 Predicted: 1 Tweet: house saved demolition moved orcas island washington
# Actual: 1.0 Predicted: 0 Tweet: tarp protecting outfield cannot moved infield getting deluged
# Actual: 1.0 Predicted: 0 Tweet: room full people lifting collide prayer excited friday night
# Actual: 1.0 Predicted: 0 Tweet: x counter acts burning alexandrian library
# Actual: 1.0 Predicted: 0 Tweet: hijacker cops back dock
# Actual: 1.0 Predicted: 0 Tweet: stage drama queen stand drama stage amp certainly never world stage would annihilated
# Actual: 1.0 Predicted: 0 Tweet: photoset hookier new stills dust storm x
# Actual: 0.0 Predicted: 1 Tweet: domestic terrorism ifs ands buts created
# Actual: 1.0 Predicted: 0 Tweet: need plants pacific cyclone seasons would help
# Actual: 1.0 Predicted: 0 Tweet: 12 would hide coldstone monterrey us 1 great place wait rainstorm
# Actual: 1.0 Predicted: 0 Tweet: chinas stock market crash summer sparked interest bargain hunt
# Actual: 0.0 Predicted: 1 Tweet: timestack photos collapse entire sunsets single mesmerizing images
# Actual: 1.0 Predicted: 0 Tweet: 99day emergency services display meeting brave police firefighters first responders help keep us safe
# Actual: 1.0 Predicted: 0 Tweet: chinas stock market crash gems rubble roimentor yycwalks
# Actual: 0.0 Predicted: 1 Tweet: obama giving false time schedule iran testing first bomb bomb nuclear suicide vest
# Actual: 1.0 Predicted: 0 Tweet: survive gloria gaynor oktaviana devi
# Actual: 1.0 Predicted: 0 Tweet: 13 ohh bush fires spain like every year one time went swimming planes getting water fight
# Actual: 0.0 Predicted: 1 Tweet: tech data overload growing demand context structure world inundated information news
# Actual: 1.0 Predicted: 0 Tweet: local family displaced fire via lets help family please
# Actual: 1.0 Predicted: 0 Tweet: dem flatliners destroy creativitybalancelongevity amp truth stand lucifer flames destruction
# Actual: 0.0 Predicted: 1 Tweet: theres choking hazard dont die get
# Actual: 1.0 Predicted: 0 Tweet: move saturday gt mirage 400 n west st raleigh nc 21 tickets
# Actual: 1.0 Predicted: 0 Tweet: bigamist first wife charged deaths second pregnant wife child 8 mothe
# Actual: 1.0 Predicted: 0 Tweet: 30wu1f2 see point countering skewed statements dumb statement dumb
# Actual: 0.0 Predicted: 1 Tweet: skinny jeans hazardous health
# Actual: 0.0 Predicted: 1 Tweet: time next week absolute pandemonium several homes around westmeath carefully
# Actual: 1.0 Predicted: 0 Tweet: urgentthere currently 3 storey building church bstop oworoshoki third mainland bridge likely collapse
# Actual: 1.0 Predicted: 0 Tweet: tricycle toddler atomic bomb fraction second decisions change landscape humanity
# Actual: 1.0 Predicted: 0 Tweet: fucking idiot gun amp hatchet yet still serious injuries glad police terminated
# Actual: 1.0 Predicted: 0 Tweet: houston nyc collide 7 gemma bowe_
# Actual: 1.0 Predicted: 0 Tweet: rt karnythia another erasureisnotequality example movies like impossible natural disaster thailand focuses white _
# Actual: 1.0 Predicted: 0 Tweet: rt_america rt rt_com eye super typhoon soudelor seen space timelapse
# Actual: 0.0 Predicted: 1 Tweet: least arent burning buildings looting stores
# Actual: 0.0 Predicted: 1 Tweet: statistically im risk getting killed cop dying airplane accident
# Actual: 1.0 Predicted: 0 Tweet: isnt showing think crashed
# Actual: 1.0 Predicted: 0 Tweet: lokis daggers pulled jammed minas thigh mina screamed grabbed leg sif
# Actual: 0.0 Predicted: 1 Tweet: lake sees dead fish poor little guy wonder happened ashley idk maybe drowned wtf
# Actual: 1.0 Predicted: 0 Tweet: liked video lexi belle oklahoma tornado victims
# Actual: 0.0 Predicted: 1 Tweet: let people surf hi waimea bay like beach ever inundated surfers
# Actual: 0.0 Predicted: 1 Tweet: proof democrats afraid trump clintons trying derail trump w meddling
# Actual: 1.0 Predicted: 0 Tweet: renewing kitchen cabinets 100
# Actual: 0.0 Predicted: 1 Tweet: summerfate intense cant believe vals dead
# Actual: 1.0 Predicted: 0 Tweet: 12 72w cree led work light bar alloy spot flood combo diving offroad 4wd boat full read_
# Actual: 1.0 Predicted: 0 Tweet: beautiful architecture nyc love fire escape routes buildings newyork_
# Actual: 1.0 Predicted: 0 Tweet: lava blast dan power red pantherattack 11
# Actual: 1.0 Predicted: 0 Tweet: people come go cigarette breaks others forest fires
# Actual: 1.0 Predicted: 0 Tweet: gunsense answer gfzs break law minuscule chance mass murderer shows
# Actual: 0.0 Predicted: 1 Tweet: taken movies took place india 2 vine
# Actual: 1.0 Predicted: 0 Tweet: secret bunker used cheney 911 look like catered ktchn staff evacuated
# Actual: 1.0 Predicted: 0 Tweet: hellfire surrounded desires careful dont let desires control afterlife
# Actual: 0.0 Predicted: 1 Tweet: mad kids innocent people nothing war got obliterated smh
# Actual: 0.0 Predicted: 1 Tweet: hot funtenna hijacking computers send data sound waves black hat 2015 prebreak best
# Actual: 1.0 Predicted: 0 Tweet: post today talk dangers interruptions annoy
# Actual: 1.0 Predicted: 0 Tweet: accidentally killed 87 day snap streak wanna accidentally fall cliff
# Actual: 0.0 Predicted: 1 Tweet: im currently burning skin
# Actual: 0.0 Predicted: 1 Tweet: truth news bbc cnn islam truth god isis terrorism quran lies
# Actual: 0.0 Predicted: 1 Tweet: people even ride metro whywebike bikecommute dysfunctionalredline wmata
# Actual: 0.0 Predicted: 1 Tweet: also loki treated nicely fandom mass murderer know
# Actual: 0.0 Predicted: 1 Tweet: changelessly handle dominant quarantine folders toward solemnity hjt
# Actual: 1.0 Predicted: 0 Tweet: youre snowstorm baby
# Actual: 1.0 Predicted: 0 Tweet: predict riot
# Actual: 1.0 Predicted: 0 Tweet: fracking ecocide eyewitness extreme weather 11 social media posts show crazy revolution
# Actual: 0.0 Predicted: 1 Tweet: attack womens health attack americas health hillary clinton shows standwithpp
# Actual: 1.0 Predicted: 0 Tweet: found cool photo mine 1952 dodge wayne bodied 4 window bus ex libby mt fire department truck ori_
# Actual: 1.0 Predicted: 0 Tweet: redscarebot duck cover rt tanstaafl23 noah_anyname socialism means mass murder houze correlation
# Actual: 1.0 Predicted: 0 Tweet: indian govt amp media take serious concern safety danger
# Actual: 1.0 Predicted: 0 Tweet: tonight attended fire romford thankfully injuries
# Actual: 1.0 Predicted: 0 Tweet: oops bounty hunters try raid phoenix police chiefs home group armed bounty hunters surrounded h
# Actual: 0.0 Predicted: 1 Tweet: esteemed journalist recalls tragic effects unaddressed childhood trauma counciling therapy newauthors hiv
# Actual: 1.0 Predicted: 0 Tweet: arsonist sets nyc vegetarian restaurant fire police newyork
# Actual: 1.0 Predicted: 0 Tweet: 1983 like shedid 911 4the public facts journalist bushs washard stopping terrorist
# Actual: 0.0 Predicted: 1 Tweet: blood pressure roof dont need extra shit
# Actual: 0.0 Predicted: 1 Tweet: tribal olap world pres recognize hazardous waste multidimensi
# Actual: 1.0 Predicted: 0 Tweet: wall noise one thing wall dust moving 60mph get blown away
# Actual: 1.0 Predicted: 0 Tweet: urgentthere currently 3 storey building church bstop oworoshoki third mainland bridge likely collapse
# Actual: 1.0 Predicted: 0 Tweet: exploring new worlds three moments explosion china miville
# Actual: 0.0 Predicted: 1 Tweet: say phil actually collapsed gravel sobbing endlessly crowd watching confused angry mad
# Actual: 1.0 Predicted: 0 Tweet: ill sfa soonpandemonium
# Actual: 0.0 Predicted: 1 Tweet: arsonist mc christ walk toronto columbus gospel
# Actual: 1.0 Predicted: 0 Tweet: sadly could save humanity ursula drowned drool protoshoggoth least sort died loved
# Actual: 0.0 Predicted: 1 Tweet: 22 tory landslide cant possibly mean waferthin majority ge2015
# Actual: 1.0 Predicted: 0 Tweet: strawberries big trouble scientists race find solution
# Actual: 0.0 Predicted: 1 Tweet: dont think paint lab building cause planning demolition since forever
# Actual: 0.0 Predicted: 1 Tweet: demi stans really think heart attack sold 56 million copies
# Actual: 0.0 Predicted: 1 Tweet: got first damage today fuckk
# Actual: 0.0 Predicted: 1 Tweet: peeped frontin jeepsunk seat tinted heat beats bumpin
# Actual: 0.0 Predicted: 1 Tweet: rspca site multiple 7 story high rise buildings next low density character residential area floods
# Actual: 1.0 Predicted: 0 Tweet: dont bother offline managed evacuate everyone including hinata go ahead cause
# Actual: 1.0 Predicted: 0 Tweet: came across fire video mineenjoyfire firemen firetruck emergency rescue 911 summertime sirens_
# Actual: 1.0 Predicted: 0 Tweet: words charlie daniels fire mountain run boys run_
# Actual: 0.0 Predicted: 1 Tweet: 19 year olds smug face dorret brings mudslide black forest gateau priceless gbbo
# Actual: 1.0 Predicted: 0 Tweet: next may ill freefrom school obligations like family best damn curfew
# Actual: 1.0 Predicted: 0 Tweet: biggest nuclear disaster ever happened
# Actual: 1.0 Predicted: 0 Tweet: 12 72w cree led work light bar alloy spot flood combo diving offroad 4wd boat full read_
# Actual: 0.0 Predicted: 1 Tweet: san jose mercury governor brown allows parole california school bus hijacker
# Actual: 0.0 Predicted: 1 Tweet: hollywood movie trapped miners released chile newsdict news chile
# Actual: 1.0 Predicted: 0 Tweet: climatechange eyewitness extreme weather 11 social media posts show crazy things anarchy
# Actual: 1.0 Predicted: 0 Tweet: governor weighs parole california school bus hijacker
# Actual: 1.0 Predicted: 0 Tweet: arsonist sets nyc vegetarian restaurant fire police newyork
# Actual: 1.0 Predicted: 0 Tweet: oops h bomb lost 70 miles okinawan coast fell ship 1965
# Actual: 1.0 Predicted: 0 Tweet: keep shape shoes amazon foot adjust shape shoe mini shoe tree stretcher shaper width extender adjustable
# Actual: 0.0 Predicted: 1 Tweet: beforeitsnews global derivatives 15 quadrillion time bomb v_
# Actual: 0.0 Predicted: 1 Tweet: strange loud impact bang noises train epsom arrive wimbledon
# Actual: 0.0 Predicted: 1 Tweet: tasted like feast famine starving trusting jack 4coffee iartg rwa tw4rw rrbc
# Actual: 1.0 Predicted: 0 Tweet: get hailstorm come 2night 9pm catch screening ft beer food
# Actual: 1.0 Predicted: 0 Tweet: watch bad fool get burned coverage year dat dude allpro practice squad material
# Actual: 0.0 Predicted: 1 Tweet: hot funtenna hijacking computers send data sound waves black hat 2015 prebreak best
# Actual: 1.0 Predicted: 0 Tweet: family mourns drowning superhero toddler rare epilepsy chicago tribune
# Actual: 1.0 Predicted: 0 Tweet: young dancer moves 300 youth attendance gmmbc youth explosion past saturday inspiring
# Actual: 0.0 Predicted: 1 Tweet: donation make difference lives survivors braininjury please donate today
# Actual: 0.0 Predicted: 1 Tweet: good un fella sorry wont get annihilated
# Actual: 0.0 Predicted: 1 Tweet: amp stat high auto deaths applies children vehicle guess run lightrail better adult
# Actual: 1.0 Predicted: 0 Tweet: squad obliteration
# Actual: 1.0 Predicted: 0 Tweet: get sis planet could huge dose obliteration
# Actual: 0.0 Predicted: 1 Tweet: upheaval high note bush opera sydney news aus
# Actual: 1.0 Predicted: 0 Tweet: btw live libertyville bc tornado
# Actual: 1.0 Predicted: 0 Tweet: fedex willing transport research specimens potential bioterror pathogens wake anthrax lab mishaps
# Actual: 0.0 Predicted: 1 Tweet: issues uploading death smoochy awakenings clips reason bicentennial man pain ass
# Actual: 1.0 Predicted: 0 Tweet: disaster impairs mental health especially vulnerable individuals
# Actual: 1.0 Predicted: 0 Tweet: lots talk susceptible ny2 shoot blight without trama wcfgt2015
# Actual: 1.0 Predicted: 0 Tweet: hot reddits new content policy goes effect many horrible subreddits banned quarantined prebreak best
# Actual: 1.0 Predicted: 0 Tweet: lightening struck amp 2 units 1 buildings development fire groton ct check fb wall recent post
# Actual: 1.0 Predicted: 0 Tweet: 8 emergency situation late year plan camp
# Actual: 1.0 Predicted: 0 Tweet: texian iliad military history texas revolution hardin stephen l
# Actual: 0.0 Predicted: 1 Tweet: trapped cat room going insane leaving pretty
# Actual: 0.0 Predicted: 1 Tweet: honestly nightmarish god driving new places always stressful shit amp hate much ugh almost crashed times
# Actual: 1.0 Predicted: 0 Tweet: come one asked obvious qn show hindu suicide bomber never heard one
# Actual: 0.0 Predicted: 1 Tweet: messed feeling like hurricane damaged broken home
# Actual: 1.0 Predicted: 0 Tweet: watched emmerdale nd dont know slightly attractive man named ross got beat nd hes dead
# Actual: 0.0 Predicted: 1 Tweet: harshness follows us better day sarah c racing thoughts screaming sirens pacing back forth
# Actual: 0.0 Predicted: 1 Tweet: day learn importance emergency exits day heartbeat stops sounding familiar
# Actual: 1.0 Predicted: 0 Tweet: omg huge crush looks necessarily dont think looks way
# Actual: 1.0 Predicted: 0 Tweet: people tattoo u allowed donate blood receive blood well
# Actual: 0.0 Predicted: 1 Tweet: falling asleep sounds thousands river plate fans stadium thunderstorm vivaargentina
# Actual: 1.0 Predicted: 0 Tweet: californians like living africas sahel desert finding water daily chore
# Actual: 0.0 Predicted: 1 Tweet: irony died thousand deaths
# Actual: 1.0 Predicted: 0 Tweet: crazy use netanyahu argument iran flush nuclear reactor toilet
# Actual: 0.0 Predicted: 1 Tweet: happy report quite tropics cyclone development expected time
# Actual: 1.0 Predicted: 0 Tweet: star wars power jedi collection 1 battle droid hasbro full read ebay
# Actual: 1.0 Predicted: 0 Tweet: newcastle schoolgirl attacked seaton delaval park pack animals led former friend newcastle
# Actual: 1.0 Predicted: 0 Tweet: call report dangerous activity tell em body bags arrival
# Actual: 1.0 Predicted: 0 Tweet: bc risky costly dont see need isnt anything totally desolate
# Actual: 0.0 Predicted: 1 Tweet: ghost literally surrounded people trapped mentally small minded individuals smh
# Actual: 0.0 Predicted: 1 Tweet: going beach jim alves means guaranteed rainstorm lucky
# Actual: 1.0 Predicted: 0 Tweet: burning like neon lights
# Actual: 1.0 Predicted: 0 Tweet: pendleton media office said fire base right horno blaze
# Actual: 0.0 Predicted: 1 Tweet: 4 second faster overtook twice crashed tru luv lt3 lt3
# Actual: 1.0 Predicted: 0 Tweet: found guys todayregarding accident airplane lol amp became fan sending love amp support cali
# Actual: 1.0 Predicted: 0 Tweet: chances many us still digging catastrophe wow needs evolve cant vanilla anymore
# Actual: 1.0 Predicted: 0 Tweet: kalmikya astrakhan volgagrad dagestan already food left locusts via
# Actual: 1.0 Predicted: 0 Tweet: still cant get thunderstormtornado woken yesterday half street still dark
# Actual: 0.0 Predicted: 1 Tweet: 3 excessive engine failure rate significant maintenance constantly emerging structural defects phew thats lot say
# Actual: 0.0 Predicted: 1 Tweet: burning man ablaze turban diva via
# Actual: 1.0 Predicted: 0 Tweet: petition heartless owner whipped horse collapsed told keep animal act
# Actual: 0.0 Predicted: 1 Tweet: come scott rice doesnt get another shot holding lefties 184 average injured
# Actual: 1.0 Predicted: 0 Tweet: stay vigilent civil liberties constant attack nativehuman myreligion
# Actual: 1.0 Predicted: 0 Tweet: mass murderer sex without touching taking clothes fanatical hygiene
# Actual: 1.0 Predicted: 0 Tweet: earnest pletchs coldblooded killing carl bivens one chapter strange life
# Actual: 0.0 Predicted: 1 Tweet: go look grizzly peak right looks like beginning dystopian apocalypse movie
# Actual: 0.0 Predicted: 1 Tweet: cooper super pooper hero dog saved drowning detected heart attack knew the_
# Actual: 0.0 Predicted: 1 Tweet: disaster averted police kill gunman hoax device atcinema
# Actual: 1.0 Predicted: 0 Tweet: bring back games past snowstorm tic tac toe battleships fast food matchwood
# Actual: 0.0 Predicted: 1 Tweet: example low food prices cause farmers go broke famine next year means simple capitalism failed feed peoplegt
# Actual: 0.0 Predicted: 1 Tweet: burned 202 calories 30 minutes walking 40 mph brisk pace myfitnesspal
# Actual: 1.0 Predicted: 0 Tweet: drowning doesnt sound half bad rn
# Actual: 0.0 Predicted: 1 Tweet: hot fiat olap world pres recognize hazardous waste multidimensiona
# Actual: 1.0 Predicted: 0 Tweet: set become huge one month wonder pornhub inundated
# Actual: 1.0 Predicted: 0 Tweet: granted like half town floods rains still whatever
# Actual: 0.0 Predicted: 1 Tweet: storm silence
# Actual: 1.0 Predicted: 0 Tweet: seattles deadliest red light runner intersections revealed
# Actual: 1.0 Predicted: 0 Tweet: senators another year determine hoffmans v coloradoavs nhlavalanche
# Actual: 0.0 Predicted: 1 Tweet: im dead two loves 1 photo heart exploded million pieces
# Actual: 1.0 Predicted: 0 Tweet: youre search powerful content improve business frustrated deluge quantit_
# Actual: 1.0 Predicted: 0 Tweet: tornadogiveaway thebookclub join
# Actual: 1.0 Predicted: 0 Tweet: whole city trapped cant leave city supposed normal sports manga wit love triangle c
# Actual: 1.0 Predicted: 0 Tweet: told drowning would lend hand
# Actual: 0.0 Predicted: 1 Tweet: check found google images something live
# Actual: 0.0 Predicted: 1 Tweet: please keep josh salyersblairhall families amp jennas friends prayers taken far soon rip
# Actual: 0.0 Predicted: 1 Tweet: hail pic
# Actual: 1.0 Predicted: 0 Tweet: want everyone know emilee worried getting milkshake supposed evacuate
# Actual: 0.0 Predicted: 1 Tweet: lee comedy working class tories prepare armageddon interestraterise
# Actual: 1.0 Predicted: 0 Tweet: angry woman openly accuses nema stealing relief materials meant idps angry internally displaced wom
# Actual: 0.0 Predicted: 1 Tweet: chinas stock market crash gems rubble forbes
# Actual: 1.0 Predicted: 0 Tweet: heat wave social autopsy disaster chicago klinenberg eric
# Actual: 0.0 Predicted: 1 Tweet: end times upon us famine war death plague presence growing stronger
# Actual: 1.0 Predicted: 0 Tweet: date release ep03 desolation set stay tuned info finalise schedule alt electro rock comingsoon
# Actual: 0.0 Predicted: 1 Tweet: cossackshussars oo hd riggd rough shelters n th gladewere kindlng glowng fires n hollow v th forest th frnch could c th
# Actual: 1.0 Predicted: 0 Tweet: fairfax co investigating firefighter khalil abdulrasheed facebook post saying police shld put body bags
# Actual: 1.0 Predicted: 0 Tweet: sinkhole west side damaging cars via
# Actual: 0.0 Predicted: 1 Tweet: cant breathe lungs collapsed
# Actual: 1.0 Predicted: 0 Tweet: latest fallout biolab safety lapses fedex longer transport anthrax amp select agent research specimens
# Actual: 0.0 Predicted: 1 Tweet: cyclists pandemonium roads today drive carefully
# Actual: 0.0 Predicted: 1 Tweet: manuscript suspiciously rejected earthquake science journal could rock world viayoutube
# Actual: 1.0 Predicted: 0 Tweet: shameful tragic
# Actual: 1.0 Predicted: 0 Tweet: kinda cool tonight heat wave finally 7amdollela 3la kulli 7aal
# Actual: 0.0 Predicted: 1 Tweet: latest updates salt river wild horse roundup via
# Actual: 1.0 Predicted: 0 Tweet: 4 equipment ego break upon dig family internet hoke excepting versus sinking term dfljev
# Actual: 1.0 Predicted: 0 Tweet: eversafe emergency auto kit weather unsafe hazardous rushhour gridlock jumperca_
# Actual: 0.0 Predicted: 1 Tweet: heros fight wars save ppl burning buildings etc im sorry u gotta pay 4 sex change be4 call u hero
# Actual: 0.0 Predicted: 1 Tweet: jesus niggaeven life hand leave stretcher
# Actual: 0.0 Predicted: 1 Tweet: nearly 35 years release captivity legislation introduced congress compensate 53_
# Actual: 1.0 Predicted: 0 Tweet: remove linkury browser hijacker
# Actual: 1.0 Predicted: 0 Tweet: watch mother nature halts australia blue mountains bushfire
# Actual: 1.0 Predicted: 0 Tweet: images famine hope christ blog happens forget god hopeinchrist
# Actual: 0.0 Predicted: 1 Tweet: question day proven eyewitness accounts always reliable
# Actual: 1.0 Predicted: 0 Tweet: holy moly crushed
# Actual: 1.0 Predicted: 0 Tweet: mudslide like chewing rubber tyre im done vaginaorcake gbbo

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred) # Compute the ROC curve by comparing the predicted probabilities (y_pred) to the true labels (y_test).
plt.figure() # Create a new figure to plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % auc) # Plot the ROC curve using the false positive rate (fpr) on the x-axis and the true positive rate (tpr) on the y-axis.
plt.plot([0, 1], [0, 1], 'k--') # Plot the diagonal line representing the ROC curve for a random classifier.
plt.legend(loc="lower right") # Add a legend to the plot, placing it in the lower right corner.
plt.show() #displaying the graph

# %%
model.save('dnn_model.h5')

# %%
from keras.models import load_model

# %%
# # Create Word Clouds
relevant_tweets = df.query("Category==1")["Cleaned_Tweet"].apply(str).str.cat(sep=' ')
not_relevant_tweets = df.query("Category==0")["Cleaned_Tweet"].apply(str).str.cat(sep=' ')

# %%
# Preprocess and generate word frequencies for relevant tweets
relevant_wordcloud = WordCloud().generate(relevant_tweets)

# %%
# Preprocess and generate word frequencies for not relevant tweets
not_relevant_wordcloud = WordCloud().generate(not_relevant_tweets)

# %%
# Plot the word clouds
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.imshow(relevant_wordcloud, interpolation="bilinear")
plt.title("Relevant Tweets")
plt.axis("off")
plt.subplot(1, 2, 2)
plt.imshow(not_relevant_wordcloud, interpolation="bilinear")
plt.title("Not Relevant Tweets")
plt.axis("off")
plt.show()

# %%
import tkinter as tk
from tkinter import messagebox
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
window = tk.Tk()
window.title("News or Tweet Classification")
window.geometry("600x400")
model = load_model("dnn_model.h5")
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['Cleaned_Tweet'])
def classify_text():
    text = entry_text.get("1.0", tk.END)
    if text:
        sequence = tokenizer.texts_to_sequences([text])
        padded_sequence = pad_sequences(sequence, padding='post', maxlen=tokenizer.num_words)
        prediction = model.predict(padded_sequence)
        result = "Relevant" if prediction >= 0.5 else "Not Relevant"
        output_text.delete("1.0", tk.END)
        output_text.insert(tk.END, result)
    else:
        messagebox.showwarning("Please enter some text")
entry_text = tk.Text(window, height=5, width=40)
entry_text.pack(pady=10)

button_classify = tk.Button(window, text="Classify", command=classify_text)
button_classify.pack(pady=10)

output_text = tk.Text(window, height=1, width=40)
output_text.pack()
window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\yaswa\anaconda3\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\yaswa\AppData\Local\Temp\ipykernel_30248\2148628697.py", line 18, in classify_text
#     prediction = model.predict(padded_sequence)
#   File "C:\Users\yaswa\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\yaswa\AppData\Local\Temp\__autograph_generated_fileagvwl62r.py", line 15, in tf__predict_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "C:\Users\yaswa\anaconda3\lib\site-packages\keras\engine\training.py", line 2041, in predict_function  *
#         return step_function(self, iterator)
#     File "C:\Users\yaswa\anaconda3\lib\site-packages\keras\engine\training.py", line 2027, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\yaswa\anaconda3\lib\site-packages\keras\engine\training.py", line 2015, in run_step  **
#         outputs = model.predict_step(data)
#     File "C:\Users\yaswa\anaconda3\lib\site-packages\keras\engine\training.py", line 1983, in predict_step
#         return self(x, training=False)
#     File "C:\Users\yaswa\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\yaswa\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 100), found shape=(None, 0)
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 1).
# 1/1 [==============================] - 0s 362ms/step
